# %% [markdown]
# # Naxos Music Library
#
#
# ## Background
#
# Based on a brief conversation with Mackenzie Miller (then UM Interactive Media grad student) in early 2019, I've decided to build a scraper to get data from the Naxos Music Library about classical music in movies. I built the scraper originally in early 2019 and now in October 2019, I'm updating the code so it can be reusable. This effort is also an example of how annoying it can be to try to scrape certain websites (I'll get more into this later).
#
# With Naxos, you can see the data organized by either [Movie Title](https://www.naxos.com/musicinmovieslist.asp?letter=A) or [Composer](https://www.naxos.com/musicinmoviescomplist.asp?letter=A). I've chosen to go with the Composer arrangement because that's how Mackenzie and I were considering the data at first, and it seems like there are less composers than movies (although I haven't verified this).
#
#
# ## The Plan
#
# 1. Get the HTML from each page and save it as a backup. Because no composer's name starts with a number (yet), I only need to scrape the 26 pages that correspond to the letters of the alphabet. There are a few letters for which there is no composer with that last name: N, O, U, and X. **I'm not exactly sure if classical music only refers to music made in a certain period or if there are composers today who do compose classical music. Because of this I'll scrape the pages now, in case there are composers added whose last name start with these letters.**
# 1. For each page, find the table inside the `<td>` element with class `style5` and then work to get the data from there. Save the data as a CSV file.
#
# @@TODO: Figure out how to save the data a JSON file.
#
#
# ---

# %% [markdown]
# The first we'll do is import the various libraries we'll be working with:
#
# * @@TODO: explain each of the libraries being used.
# * @@TODO: add this info to the .README file

# %%
import requests
from bs4 import BeautifulSoup
import lxml
from time import sleep
import csv
from string import ascii_uppercase
import codecs

# %% [markdown]
# The url structure for the composers whose last names start with the letter `A` is:
#
# `https://www.naxos.com/musicinmoviescomplist.asp?letter=A`
#
# If we want to get the composers whose last names start with the letter `B` we just have to change what comes after the `=` in the url. We can conveniently get the entire alphabet in uppercase as a string by using `ascii_uppercase` from the `string` module.
#
# To get the html for the pages we'll loop through the string and request each page. We'll save the scraped HTML to a folder that will follow the pattern: `YYYY-MM-pages`. I'm doing this in October 2019, so the folder will be `2019-10-pages`. Currently, this is a manual process, but I hope to automate it.
#
# * @@TODO: automate the month/year pattern for folder creation
# * @@TODO: automate the folder creation in the notebook

# %%
base_url = "https://www.naxos.com/musicinmoviescomplist.asp?letter="
year = 2019
month = 10
out_folder = "-".join([str(year), str(month), "pages"])

# %% [markdown]
# We'll use the `requests` library to request the html code of each page and save it for processing. This part of the code requires an internet connection, but the rest of the notebook does not. We'll append the path to each file to a list that we'll use when working with our data.

# %%
pages = []

for letter in ascii_uppercase:
    out_file = out_folder + "/" + letter + ".html"

    complete_url = base_url + letter
    response = requests.get(complete_url)
    page = response.text
    
    pages.append(out_file)
    open(out_file, "w+").write(page)

# %% [markdown]
# Before we process the 26 files, let's look at some examples so we can build out the overall scraper. The two big cases we have to write code for are:
#
# 1. When we have composer data on the page.
# 1. When we don't have composer data on the page.
#
# Let's start with the page for composers who have last names starting with the letter P.

# %%
case1_file = codecs.open(pages[15], 'r', 'utf-8')
case1 = case1_file.read()

# %% [markdown]
# With this first case, we'll identify any additional formatting and prepping of the file that may need to be done and then surf the html to find the fields we could want.
#
# The first thing to note is that the files are encoded as `ISO-8859-1` and not `UTF-8`. Before I pass them on to Beautiful Soup for the parsing, I want them to be in `UTF-8`.
#
# I'll also remove the invisible characters: `\n`, `\t`, and `\r` to make future parsing quicker

# %%
case1 = case1.replace("\n", "").replace("\t", "").replace("\r", "")

soup = BeautifulSoup(case1, "lxml")

# %% [markdown]
# After inspecting the website, I noticed that the table we want to scrape is inside a `<td>` element with a class attribute `style5`. The table that is a child of this `<td class="style5"></td>` element is what we care about. Let's get that first

# %%
table = soup.find("td", class_="style5").find("table")

# %% [markdown]
# Within this table, the composers are each within `<b></b>` tags. Let's grab those first.

# %%
composers = table.find_all("b")
composers
# Out:
# [<b>PACHELBEL, JOHANN</b>,
#  <b>PAGANINI, NICOLO</b>,
#  <b>PAISIELLO, GIOVANNI</b>,
#  <b>PALESTRINA, GIOVANNI PIERLUIGI DA</b>,
#  <b>PALSCHAU, JOHANN GOTTFRIED WILHELM</b>,
#  <b>PARRY, HUBERT</b>,
#  <b>PART, ARVO</b>,
#  <b>PEARSALL, ROBERT LUCAS</b>,
#  <b>PENDERECKI, KRZYSZTOF</b>,
#  <b>PERGOLESI, GIOVANNI BATTISTA</b>,
#  <b>PITONI, GIUSEPPE OTTAVIO</b>,
#  <b>PONCHIELLI, AMILCARE</b>,
#  <b>POULENC, FRANCIS</b>,
#  <b>PROKOFIEV, SERGEY</b>,
#  <b>PUCCINI, GIACOMO</b>,
#  <b>PURCELL, HENRY</b>]

# %% [markdown]
# After the composer info, we want the meat of the data: the composer's music that was used, and the movie it was used in. This information is conveniently packaged in various `<div></div>` containers, but these div containers are in the next row. From the composer name, we have to climb out to the `<tr></tr>` level and then find the next row. Let's try it with the first composer in this list:

# %%
composer = composers[0]
composer_row = table.find(text=composer.text).parent.parent.parent
composer_row
# Out:
# <tr><td bgcolor="#EEEEEE"><b>PACHELBEL, JOHANN</b></td></tr>

# %% [markdown]
# Now we have to find the next row in the table.

# %%
music_row = composer_row.next_sibling.next_sibling
music_row
# Out:
# <tr><td bgcolor="#ffffff" class="style5"> <div style="border-top:1px dotted #999999; border-bottom:1px dotted #999999; padding:3px 0px; margin:0px 0px">Canon in D major <span class="style1">(<a href="https://www.naxos.com/catalogue/item.asp?item_code=8.550104">8.550104</a> )</span><br/><i>Brooklyn (2015) <br/> Dude, Where's My Car? (2000) <br/> Father of the Bride (1991) <br/> Hush <br/> Laggies (2014) <br/> Me Before You (2016) <br/> Nothing to Lose (1997) <br/> Ordinary People (1980) <br/> Queens Logic (1991) <br/> Runaway Bride (1999) <br/> Sing (2016) <br/> Zoolander (2001)</i><br/> </div> </td></tr>

# %% [markdown]
# There is a div for each piece of a composer that was used in a movie. Let's get them:

# %%
pieces_in_movies = music_row.find_all("div")
pieces_in_movies
# Out:
# [<div style="border-top:1px dotted #999999; border-bottom:1px dotted #999999; padding:3px 0px; margin:0px 0px">Canon in D major <span class="style1">(<a href="https://www.naxos.com/catalogue/item.asp?item_code=8.550104">8.550104</a> )</span><br/><i>Brooklyn (2015) <br/> Dude, Where's My Car? (2000) <br/> Father of the Bride (1991) <br/> Hush <br/> Laggies (2014) <br/> Me Before You (2016) <br/> Nothing to Lose (1997) <br/> Ordinary People (1980) <br/> Queens Logic (1991) <br/> Runaway Bride (1999) <br/> Sing (2016) <br/> Zoolander (2001)</i><br/> </div>]

# %% [markdown]
# We have to parse each one, but let's start with the first piece.

# %%
piece1 = pieces_in_movies[0]
piece1
# Out:
# <div style="border-top:1px dotted #999999; border-bottom:1px dotted #999999; padding:3px 0px; margin:0px 0px">Canon in D major <span class="style1">(<a href="https://www.naxos.com/catalogue/item.asp?item_code=8.550104">8.550104</a> )</span><br/><i>Brooklyn (2015) <br/> Dude, Where's My Car? (2000) <br/> Father of the Bride (1991) <br/> Hush <br/> Laggies (2014) <br/> Me Before You (2016) <br/> Nothing to Lose (1997) <br/> Ordinary People (1980) <br/> Queens Logic (1991) <br/> Runaway Bride (1999) <br/> Sing (2016) <br/> Zoolander (2001)</i><br/> </div>

# %% [markdown]
# For each time music was used we have a few fields:
#
# * name of the piece
# * link to the piece in the Naxos catalog. We can also get the item code from here.
# * the movie(s) the piece was in. This field also currently contains the year the movie was produced, and we'll isolate that field when we clean the data later.
#
# Our next goal is to identify each of these areas with some BeautifulSoup query. Let's try to find the name of the piece first

# %%
piece_name = piece1.find("span").previous_sibling
piece_name
# Out:
# 'Canon in D major '

# %% [markdown]
# This is how we can get the name of the piece based on the html code we can access. Looking at this, we can strip the field to get rid of traling spaces before or after the title.

# %%
piece_name = piece1.find("span").previous_sibling.strip()
piece_name
# Out:
# 'Canon in D major'

# %% [markdown]
# Now that we have the name, let's look for the piece's item code and url in the Naxos catalog.

# %%
piece_url = piece1.find("span").find("a")["href"]
piece_url
# Out:
# 'https://www.naxos.com/catalogue/item.asp?item_code=8.550104'

# %%
piece_item_code = piece1.find("span").find("a").text
piece_item_code
# Out:
# '8.550104'

# %% [markdown]
# The last thing we need is the movies the piece is in. The movies are enclosed within `<i></i>` tags and if there are multiple movies for a piece (like Johann Pachelbel's Canon in D), there are `<br>` in the between the movies. I'll address the different movies when I get to tidying the data.

# %%
movie_list = piece1.find("i")
movie_list
# Out:
# <i>Brooklyn (2015) <br/> Dude, Where's My Car? (2000) <br/> Father of the Bride (1991) <br/> Hush <br/> Laggies (2014) <br/> Me Before You (2016) <br/> Nothing to Lose (1997) <br/> Ordinary People (1980) <br/> Queens Logic (1991) <br/> Runaway Bride (1999) <br/> Sing (2016) <br/> Zoolander (2001)</i>

# %% [markdown]
# Now that we figured out these steps, let's build things back up. And try to get all the info for the different composers on this page:

# %%
data_list = []

for composer in composers:
    name = composer.text
    composer_row = table.find(text=composer.text).parent.parent.parent
    music_row = composer_row.next_sibling.next_sibling
    pieces = music_row.find_all("div")
    for piece in pieces:
        piece_name = piece.find("span").previous_sibling.strip()
        piece_url = piece.find("span").find("a")["href"]
        piece_item_code = piece.find("span").find("a").text
        movie_list = piece.find("i").text.replace("  ","?;")
        data_list.append([name, piece_name, piece_url, piece_item_code, movie_list])

# %%
data_list
# Out:
# [['PACHELBEL, JOHANN',
#   'Canon in D major',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550104',
#   '8.550104',
#   "Brooklyn (2015)?;Dude, Where's My Car? (2000)?;Father of the Bride (1991)?;Hush?;Laggies (2014)?;Me Before You (2016)?;Nothing to Lose (1997)?;Ordinary People (1980)?;Queens Logic (1991)?;Runaway Bride (1999)?;Sing (2016)?;Zoolander (2001)"],
#  ['PAGANINI, NICOLO',
#   '24 Caprices, Op. 1: No. 20 in D major',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550717',
#   '8.550717',
#   'Magic Bow (The) (1946)'],
#  ['PAGANINI, NICOLO',
#   'Centone di sonate, Op. 64, MS 112: Sonata No. 3 in C major',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553141',
#   '8.553141',
#   'Gallipoli (1981)'],
#  ['PAGANINI, NICOLO',
#   'Violin Concertos Nos. 1 & 2',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550649',
#   '8.550649',
#   'Magic Bow (The) (1946)'],
#  ['PAISIELLO, GIOVANNI',
#   'Il barbiere di Siviglia (The Barber of Seville): Saper bramate',
#   'https://www.naxos.com/catalogue/item.asp?item_code=CDS417',
#   'CDS417',
#   'Barry Lyndon (1975)'],
#  ['PALESTRINA, GIOVANNI PIERLUIGI DA',
#   'Missa Hodie Christus natus est: Kyrie',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550836',
#   '8.550836',
#   'Nymphomaniac: Vol. I (2013)'],
#  ['PALSCHAU, JOHANN GOTTFRIED WILHELM',
#   'Harpsichord Concerto in C major: II. Andante',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.226040',
#   '8.226040',
#   'Royal Affair (A) (En kongelig affaere) (2012)'],
#  ['PARRY, HUBERT',
#   'Jerusalem',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553981',
#   '8.553981',
#   'Blue Mountain State: The Rise of Thadland (2016)?;Chariots of Fire?;Loneliness of the Long Distance Runner (The) (1962)?;Man Who Fell to Earth (The) (1976)'],
#  ['PART, ARVO',
#   'Annum per annum',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.558182-83',
#   '8.558182-83',
#   'Thin Red Line (The) (1998)'],
#  ['PART, ARVO',
#   'Berliner Messe',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.557299',
#   '8.557299',
#   'Avengers: Age of Ultron (2015)'],
#  ['PART, ARVO',
#   'Cantus in Memory of Benjamin Britten for Strings and Bell',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553750',
#   '8.553750',
#   'Japon (2002)?;Kind of Hush (A) (1999)?;Mia Madre (2015)?;Meet Joe Black (1998)?;Winter Sleepers (1997)'],
#  ['PART, ARVO',
#   'Festina Lente for Strings and Harp Ad Libitum',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553750',
#   '8.553750',
#   'Mia Madre (2015)'],
#  ['PART, ARVO',
#   'Fratres for Eight Cellos',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553750',
#   '8.553750',
#   'To the Wonder (2012)'],
#  ['PART, ARVO',
#   'Fur Alina',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.572525',
#   '8.572525',
#   'Mia Madre (2015)'],
#  ['PART, ARVO',
#   "My Heart's in the Highlands",
#   'https://naxosmusiclibrary.com/catalogue/item.asp?cid=DCD34060',
#   'DCD34060',
#   'Grande bellezza (La) (The Great Beauty) (2013)'],
#  ['PART, ARVO',
#   'Pari intervallo (version for organ)',
#   'https://naxosmusiclibrary.com/catalogue/item.asp?cid=BC94960',
#   'BC94960',
#   'Mia Madre (2015)'],
#  ['PART, ARVO',
#   'Silouans Song',
#   'https://naxosmusiclibrary.com/catalogue/item.asp?cid=825646080700',
#   '825646080700',
#   'Mia Madre (2015)'],
#  ['PART, ARVO',
#   'Spiegel im Spiegel',
#   'https://www.naxos.com/catalogue/item.asp?item_code=9.70214',
#   '9.70214',
#   'Hoje Eu Quero Voltar Sozinho (The Way He Looks) (2014)?; This Must Be the Place (2011)'],
#  ['PART, ARVO',
#   'Tabula Rasa',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554591',
#   '8.554591',
#   'Mia Madre (2015)'],
#  ['PEARSALL, ROBERT LUCAS',
#   'In dulci jubilo',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550589',
#   '8.550589',
#   'Still Alice (2014)'],
#  ['PENDERECKI, KRZYSZTOF',
#   'De natura sonoris No. 1',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.572482',
#   '8.572482',
#   'Shining (The) (1980)?;Twilight (2008)'],
#  ['PENDERECKI, KRZYSZTOF',
#   'Kosmogonia',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.572481',
#   '8.572481',
#   'Wild at Heart (1990)'],
#  ['PENDERECKI, KRZYSZTOF',
#   'Polymorphia',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.557980',
#   '8.557980',
#   'Exorcist (The) (1973)?;Fearless (1993)?;Shining (The) (1980)'],
#  ['PENDERECKI, KRZYSZTOF',
#   'String Quartet No. 1',
#   'https://naxosmusiclibrary.com/catalogue/item.asp?cid=BIS-CD-652',
#   'BIS-CD-652',
#   'Exorcist (The) (1973)'],
#  ['PENDERECKI, KRZYSZTOF',
#   'Tren (Threnody), "To the Victims of Hiroshima"',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554491',
#   '8.554491',
#   'People Under the Stairs (The) (1991)'],
#  ['PENDERECKI, KRZYSZTOF',
#   'Utrenja',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.572031',
#   '8.572031',
#   'Shining (The) (1980)'],
#  ['PERGOLESI, GIOVANNI BATTISTA',
#   'Salve Regina in C minor',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.557447',
#   '8.557447',
#   'Farinelli Il Castrato (1994)'],
#  ['PERGOLESI, GIOVANNI BATTISTA',
#   'Stabat Mater',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.557447',
#   '8.557447',
#   'Jesus of Montreal (1989)'],
#  ['PERGOLESI, GIOVANNI BATTISTA',
#   'Stabat Mater: Fac, ut ardeat cor meum',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.557447',
#   '8.557447',
#   'Tom & Viv (1994)'],
#  ['PERGOLESI, GIOVANNI BATTISTA',
#   'Stabat Mater: Quando corpus morietur',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.557447',
#   '8.557447',
#   'Amadeus (1984)'],
#  ['PITONI, GIUSEPPE OTTAVIO',
#   'Cantate Domino',
#   'https://www.classicsonline.com/catalogue/product.aspx?cid=5902547006178',
#   '5902547006178',
#   'Love Is Strange (2014)'],
#  ['PONCHIELLI, AMILCARE',
#   'La Gioconda: Cielo e mar',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550497',
#   '8.550497',
#   'Yes, Giorgio (1982)'],
#  ['PONCHIELLI, AMILCARE',
#   'La Gioconda: Dance of the Hours',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550081',
#   '8.550081',
#   'Fantasia (1940)?;Sour Grapes (1998)'],
#  ['POULENC, FRANCIS',
#   '3 movements perpetuels: I. Assez modere',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553930',
#   '8.553930',
#   'Grande bellezza (La) (The Great Beauty) (2013)?;Rope (1948)'],
#  ['POULENC, FRANCIS',
#   'Improvisation No. 15 in C minor: Tres vite',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553931',
#   '8.553931',
#   'Call Me by Your Name (2017)'],
#  ['POULENC, FRANCIS',
#   'Nocturne No. 1 in C major: Sans trainer',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553929',
#   '8.553929',
#   'Henry & June (1990)'],
#  ['POULENC, FRANCIS',
#   "Leocadia: Valse des chemins de l'amour",
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553615',
#   '8.553615',
#   'Henry & June (1990)'],
#  ['PROKOFIEV, SERGEY',
#   'Alexander Nevsky, Op. 78: II. Song about Alexander Nevsky',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.555710',
#   '8.555710',
#   'Anna Karenina (1997)?;Love and Death (1975)'],
#  ['PROKOFIEV, SERGEY',
#   'Alexander Nevsky, Op. 78: III. The Crusaders in Pskov',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.555710',
#   '8.555710',
#   'Apostate (The) (2015)'],
#  ['PROKOFIEV, SERGEY',
#   'Alexander Nevsky, Op. 78: V. The Battle on Ice',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.555710',
#   '8.555710',
#   'Apostate (The) (2015)?;Children of the Revolution (1996)'],
#  ['PROKOFIEV, SERGEY',
#   "Alexander Nevsky, Op. 78: VII. Alexander's Entry into Pskov",
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.555710',
#   '8.555710',
#   'Children of the Revolution (1996)'],
#  ['PROKOFIEV, SERGEY',
#   'Cinderella, Op. 87',
#   'https://naxosmusiclibrary.com/catalogue/item.asp?cid=3700403528336',
#   '3700403528336',
#   'Avengers: Age of Ultron (2015)'],
#  ['PROKOFIEV, SERGEY',
#   'Cinderella, Op. 87: Act III: Amoroso',
#   'https://naxosmusiclibrary.com/catalogue/item.asp?cid=3700403528336',
#   '3700403528336',
#   'Joy (2015)'],
#  ['PROKOFIEV, SERGEY',
#   'Lieutenant Kije Suite, Op. 60',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554057',
#   '8.554057',
#   'Children of the Revolution (1996)?;Isle of Dogs (2018)'],
#  ['PROKOFIEV, SERGEY',
#   "Lieutenant Kije Suite, Op. 60: III. Kije's Wedding",
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554057',
#   '8.554057',
#   'Crimson Tide (1995)?;Doc Hollywood (1991)?;Love and Death (1975)'],
#  ['PROKOFIEV, SERGEY',
#   'Lieutenant Kije Suite, Op. 60: IV. Troika',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554057',
#   '8.554057',
#   'Love and Death (1975)'],
#  ['PROKOFIEV, SERGEY',
#   'Peter and the Wolf, Op. 67',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550499',
#   '8.550499',
#   "Animal House (National Lampoon's Animal House) (1978)?;Blade Runner 2049 (2017)?;Sour Grapes (1998)?;State of Play (2009)"],
#  ['PROKOFIEV, SERGEY',
#   'Peter and the Wolf, Op. 67: II. The Bird',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550499',
#   '8.550499',
#   'Minions (2015)'],
#  ['PROKOFIEV, SERGEY',
#   'Piano Sonata No. 7 in B-flat major, Op. 83: III. Precipitato',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553021',
#   '8.553021',
#   'Couch in New York (A) (1996)?;Glenn Gould (32 Short Films about) (1993)'],
#  ['PROKOFIEV, SERGEY',
#   'Romeo and Juliet, Op. 64',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553184-85',
#   '8.553184-85',
#   'Center Stage (2000)'],
#  ['PROKOFIEV, SERGEY',
#   'Romeo and Juliet, Op. 64: Balcony Scene',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553184-85',
#   '8.553184-85',
#   'Turning Point (1977)'],
#  ['PROKOFIEV, SERGEY',
#   'Romeo and Juliet, Op. 64: Dance of the Knight',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553184-85',
#   '8.553184-85',
#   'Purely Belter (2000)'],
#  ['PROKOFIEV, SERGEY',
#   'The Love for 3 Oranges Suite, Op. 33bis: III. March',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550381',
#   '8.550381',
#   'Love and Death (1975)'],
#  ['PROKOFIEV, SERGEY',
#   'Violin Concerto No. 2 in G minor, Op. 63',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553494',
#   '8.553494',
#   'Analyze This (1999)'],
#  ['PUCCINI, GIACOMO',
#   'Gianni Schicchi: Firenze e come un albero fiorito',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660111',
#   '8.660111',
#   'Room With a View (A) (1985)'],
#  ['PUCCINI, GIACOMO',
#   'Gianni Schicchi: O mio babbino caro',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660111',
#   '8.660111',
#   "Assassins (1995)?;Boxing Helena (1993)?;Captain Corelli's Mandolin (2001)?;G.I. Jane (1997)?;Italian for Beginners (Italiensk for begyndere) (2000)?;Julien Donkey-Boy (1999)?;Metro Manila (2013)?;Mystery Men (1999)?;Now You See Me 2 (2016)?;Prizzi's Honor (1985)?;Room With a View (A) (1985)?;Sing (2016)?;Speed 2: Cruise Control (1997)?;Tinseltown (1997)?;White Palace (1990)"],
#  ['PUCCINI, GIACOMO',
#   'La Boheme: Che gelida manina',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553151',
#   '8.553151',
#   "Crew (The) (2000)?;Great Caruso (The) (1951)?;Midsummer Night's Dream (A) (1999)?;Moonstruck (1987)?;One Chance (2013)?;Pushing Tin (1999)"],
#  ['PUCCINI, GIACOMO',
#   'La Boheme: Donde lieta usci',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553151',
#   '8.553151',
#   'Moonstruck (1987)'],
#  ['PUCCINI, GIACOMO',
#   'La boheme: O soave fanciulla',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553151',
#   '8.553151',
#   'Awakenings (1990)?;House of Last Things (The Last House) (2013)?;Moonstruck (1987)?;One Chance (2013)'],
#  ['PUCCINI, GIACOMO',
#   "La Boheme: Quando me'n vo'",
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553151',
#   '8.553151',
#   'Boxing Helena (1993)?;Mad City (1997)?;Moonstruck (1987)'],
#  ['PUCCINI, GIACOMO',
#   'La Boheme: Si, mi chiamo Mimi',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553151',
#   '8.553151',
#   'Good Thief (The) (I) (2002)?;Love Letter (The) (1999)'],
#  ['PUCCINI, GIACOMO',
#   'La Boheme: Sono andati',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553151',
#   '8.553151',
#   'Deep Impact (1998)?;Deer Hunter (1978)?;Heavenly Creatures (1994)'],
#  ['PUCCINI, GIACOMO',
#   'La Rondine: Chi il bel sogno di Doretta',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550605',
#   '8.550605',
#   'Hoodlum (1997)?;Room With a View (A) (1985)'],
#  ['PUCCINI, GIACOMO',
#   'Madama Butterfly',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660015-16',
#   '8.660015-16',
#   "House! (2000)?;Men, Women: User's Manual (1996)"],
#  ['PUCCINI, GIACOMO',
#   'Madama Butterfly: Bimba dagli occhi pieni ci malia',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660015-16',
#   '8.660015-16',
#   'Diamond Hunters (The)'],
#  ['PUCCINI, GIACOMO',
#   'Madama Butterfly: Con onor muore',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660015-16',
#   '8.660015-16',
#   'Fatal Attraction (1987)?;Sing (2016)'],
#  ['PUCCINI, GIACOMO',
#   'Madama Butterfly: Ecco! Son giunte',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553152',
#   '8.553152',
#   'House of Last Things (The Last House) (2013)?;Tetro (2009)'],
#  ['PUCCINI, GIACOMO',
#   'Madama Butterfly: Humming Chorus',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660015-16',
#   '8.660015-16',
#   'Jennifer Eight (Jennifer 8) (1992)?;Heavenly Creatures (1994)?;Natural Born Killers (1994)?;Tetro (2009)?;Under the Tuscan Sun (2003)'],
#  ['PUCCINI, GIACOMO',
#   'Madama Butterfly: Vogliatemi bene',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660015-16',
#   '8.660015-16',
#   'Death in Venice (1971)?;Household Saints (1993)?;Mona Lisa (1986)'],
#  ['PUCCINI, GIACOMO',
#   'Madame Butterfly: Un bel di, vedremo',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660015-16',
#   '8.660015-16',
#   "Bohemian Rhapsody (2018)?;Fatal Attraction (1987)?;M. Butterfly (1993)?;My Geisha (1962)?;One Fine Day (1996)?;Peter's Friends (1992)?;Riot (2018)?;Second Skin?;Victor/Victoria (1995)"],
#  ['PUCCINI, GIACOMO',
#   'Manon Lescaut: Donna non vidi mai simile a questa!',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660019-20',
#   '8.660019-20',
#   'Yes, Giorgio (1982)?;Victoria & Abdul (2017)'],
#  ['PUCCINI, GIACOMO',
#   'Manon Lescaut: In Quelle Trine Morbide',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660019-20',
#   '8.660019-20',
#   'All About the Benjamins (2002)'],
#  ['PUCCINI, GIACOMO',
#   "Manon Lescaut: L'ho abdandonato",
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660019-20',
#   '8.660019-20',
#   'Anywhere But Here (1999)'],
#  ['PUCCINI, GIACOMO',
#   'Manon Lescaut: Sola, perduta, abbandonata',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550606',
#   '8.550606',
#   'Hannah and Her Sisters (1986)'],
#  ['PUCCINI, GIACOMO',
#   'Tosca: E lucevan le stelle',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660001-02',
#   '8.660001-02',
#   'Great Caruso (The) (1951)?;Heavenly Creatures (1994)?;House! (2000)?;House of Last Things (The Last?;House) (2013)?;Jagarna (The Hunters) (1996)?;Man Who Cried (The) (2000)?;Serpico (1973)'],
#  ['PUCCINI, GIACOMO',
#   'Tosca: Recondita armonia',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660001-02',
#   '8.660001-02',
#   '40 Days and 40 Nights (2002)?;Love Letter (The) (1999)'],
#  ['PUCCINI, GIACOMO',
#   "Tosca: Vissi d'arte, vissi d'amore",
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660001-02',
#   '8.660001-02',
#   'Copycat (1995)?;Faithful (1996)?;Kid Stays in the Picture (The) (2002)?;Kin?;Not Without My Daughter (1991)?;Quartet (2012)?;Yves Saint Laurent (2014)'],
#  ['PUCCINI, GIACOMO',
#   'Turandot',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660089-90',
#   '8.660089-90',
#   'Centaurus (2015)'],
#  ['PUCCINI, GIACOMO',
#   'Turandot: Nessun dorma!',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660089-90',
#   '8.660089-90',
#   'Bend it Like Beckham (2002)?;Boxing Helena (1993)?;Boy Meets Girl (1994)?;Castaway (1986)?;Chasing Liberty (2004)?;House! (2000)?;Killing Fields (The) (1984)?;Mar adentro (The Sea Inside) (I) (2004)?;Mirror Has Two Faces (The) (1996)?;Mission: Impossible - Rogue Nation (2015)?;One Chance (2013)?;Sing (2016)?;Sum of All Fears (The) (2002)?;Toys (1992)?;Witches of Eastwick (The) (1987)?;Yes, Giorgio (1982)'],
#  ['PUCCINI, GIACOMO',
#   'Turandot: Popolo di Pekino!',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660089-90',
#   '8.660089-90',
#   'Mission: Impossible - Rogue Nation (2015)'],
#  ['PUCCINI, GIACOMO',
#   'Turandot: Signore, ascolta!',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660089-90',
#   '8.660089-90',
#   'Bohemian Rhapsody (2018)'],
#  ['PUCCINI, GIACOMO',
#   'Turandot: Tu, che di gel sei cinta',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660089-90',
#   '8.660089-90',
#   'Life of David Gale (The) (2003)'],
#  ['PURCELL, HENRY',
#   'A New Ground in E minor, Z.T682',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553982',
#   '8.553982',
#   'Restoration'],
#  ['PURCELL, HENRY',
#   'Abdelazar Suite: V. Minuet',
#   'https://www.naxos.com/catalogue/item.asp?item_code=SVC-108HD',
#   'SVC-108HD',
#   'Restoration'],
#  ['PURCELL, HENRY',
#   'Dido and Aeneas, Z. 626 : Overture',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553108',
#   '8.553108',
#   'Before Sunrise (1995)'],
#  ['PURCELL, HENRY',
#   'Dido and Aeneas, Z. 626 : When I am laid in earth',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553108',
#   '8.553108',
#   'Last Supper (The)?;Man Who Cried (The) (2000)?;Mr Turner (2014)'],
#  ['PURCELL, HENRY',
#   'King Arthur, Z. 628, "The British Worthy": Overture',
#   'https://www.naxos.com/catalogue/item.asp?item_code=9.81079-80',
#   '9.81079-80',
#   'Restoration'],
#  ['PURCELL, HENRY',
#   'King Arthur, Z. 628, "The British Worthy": Second Overture',
#   'https://www.naxos.com/catalogue/item.asp?item_code=9.81079-80',
#   '9.81079-80',
#   'Restoration'],
#  ['PURCELL, HENRY',
#   'Music on the Death of Queen Mary: March, Z. 860A',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553129',
#   '8.553129',
#   'Clockwork Orange (A) (1971)'],
#  ['PURCELL, HENRY',
#   'O solitude, my sweetest choice, Z. 406',
#   'https://www.naxos.com/catalogue/item.asp?item_code=OC870',
#   'OC870',
#   'Brand New Testament (The) (2015)?;Tout nouveau testament (Le) aka The Brand New Testament (2015)'],
#  ['PURCELL, HENRY',
#   'Oedipus, King of Thebes, Z. 583: Music for a While',
#   'https://www.naxos.com/catalogue/item.asp?item_code=OC870',
#   'OC870',
#   'Favourite (The) (2018)'],
#  ['PURCELL, HENRY',
#   'Remember not, Lord, our offences, Z. 50',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553129',
#   '8.553129',
#   'Splitting Heirs (1993)'],
#  ['PURCELL, HENRY',
#   'Round O, Z. 684, "Abdelazer"',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553982',
#   '8.553982',
#   'Mimic'],
#  ['PURCELL, HENRY',
#   'The Fairy Queen, Z. 629',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550660-61',
#   '8.550660-61',
#   'Restoration'],
#  ['PURCELL, HENRY',
#   "The Gordion Knot Unty'd, Z. 597",
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.570149',
#   '8.570149',
#   'Kramer vs. Kramer (1979)'],
#  ['PURCELL, HENRY',
#   'The Indian Queen, Z. 630: The Masque of Fame and Envy',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553752',
#   '8.553752',
#   'Restoration'],
#  ['PURCELL, HENRY',
#   'The Indian Queen, Z. 630: Trumpet Tune',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.556839',
#   '8.556839',
#   'Other Sister (The) (1999)'],
#  ['PURCELL, HENRY',
#   'Trumpet Sonata in D major, Z. 850',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553444',
#   '8.553444',
#   'Kramer vs. Kramer (1979)'],
#  ['PURCELL, HENRY',
#   'Trumpet Sonata in D major, Z. 850: II. Adagio',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553444',
#   '8.553444',
#   'Favourite (The) (2018)'],
#  ['PURCELL, HENRY',
#   'Welcome to all the pleasures: Here the Deities Approve',
#   'https://www.classicsonline.com/catalogue/product.aspx?cid=722056213325',
#   '722056213325',
#   'Restoration']]

# %% [markdown]
# This seems to work! Let's try it on a page with not table and see what we need to add. We'll start the same way:

# %%
case2= codecs.open(pages[13], 'r', 'utf-8').read()
case2 = case2.replace("\n", "").replace("\t", "").replace("\r", "")

soup2 = BeautifulSoup(case2, "lxml")

# %% [markdown]
# And now we'll look into finding the composers. I'm compressing things that we did more openly before.

# %%
soup2.find("td", class_="style5").find("table").find_all("b")
# Out:
# []

# %% [markdown]
# By looking for the composers we get an empty table. We could build a checkpoint around the composer names. If we can find composers, proceed with the scraping, otherwise pass to the next page. But we can also take advantage of this neat thing with lists:

# %%
for i in []: 
    print(2)
print(1)
# Out:
# 1

# %%
for item in []: 
    print("yes")

print("no")
# Out:
# no

# %% [markdown]
# If the list is empty, the inside of a for-loop will never get executed. So we don't really have to add anything.
#
# Now we can move to extending what we did for the letter `P` to all the other letters.

# %%
untidy_data = [["composer", "piece", "piece_url", "piece_item_code", "movie_list"]]

for page in pages:
    file = codecs.open(page, "r", "utf-8").read().replace("\n", "").replace("\t", "").replace("\r", "")
    soup = BeautifulSoup(file, "lxml")
    
    table = soup.find("td", class_="style5").find("table")
    composers = table.find_all("b")
    for composer in composers:
        name = composer.text
        composer_row = table.find(text=composer.text).parent.parent.parent
        music_row = composer_row.next_sibling.next_sibling
        pieces = music_row.find_all("div")
        for piece in pieces:
            piece_name = piece.find("span").previous_sibling.strip()
            piece_url = piece.find("span").find("a")["href"]
            piece_item_code = piece.find("span").find("a").text
            movie_list = piece.find("i").text.replace("  ","?;")
            untidy_data.append([name, piece_name, piece_url, piece_item_code, movie_list])
    
print("done")
# Out:
# done

# %%
untidy_data
# Out:
# [['composer', 'piece', 'piece_url', 'piece_item_code', 'movie_list'],
#  ['ADAM, ADOLPHE',
#   'Giselle: Apparition de Giselle',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550755-56',
#   '8.550755-56',
#   'Red Shoes (The) (1948)'],
#  ['ADAM, ADOLPHE',
#   "Giselle: Entree d'Hilarion, scene et fugue des Wilis",
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550755-56',
#   '8.550755-56',
#   'Red Shoes (The) (1948)'],
#  ['ADAM, ADOLPHE',
#   'Giselle: Pas de deux des jeunes paysans',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550755-56',
#   '8.550755-56',
#   'Red Shoes (The) (1948)'],
#  ['ADAM, ADOLPHE',
#   'Giselle: Pas des premieres Wilis',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550755-56',
#   '8.550755-56',
#   'Red Shoes (The) (1948)'],
#  ['ADAMS, JOHN',
#   'China Gates',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.559285',
#   '8.559285',
#   'Call Me by Your Name (2017)'],
#  ['ADAMS, JOHN',
#   'Hallelujah Junction',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.559285',
#   '8.559285',
#   'Call Me by Your Name (2017)'],
#  ['ADAMS, JOHN',
#   'Harmonium: No. 3. Wild Nights',
#   'https://naxosmusiclibrary.com/catalogue/item.asp?cid=603497121168',
#   '603497121168',
#   'Birdman: Or (The Unexpected Virtue of Ignorance) (2014)'],
#  ['ADAMS, JOHN',
#   'Phrygian Gates',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.559285',
#   '8.559285',
#   'Call Me by Your Name (2017)'],
#  ['ADAMS, JOHN',
#   'The Death of Klinghoffer: Chorus of the Exiled Palestinians',
#   'https://naxosmusiclibrary.com/catalogue/item.asp?cid=603497121168',
#   '603497121168',
#   'Birdman: Or (The Unexpected Virtue of Ignorance) (2014)'],
#  ['ALBENIZ, ISAAC',
#   'Asturias',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553999',
#   '8.553999',
#   'Talk of Angels (1998)'],
#  ['ALBENIZ, ISAAC',
#   "Chant d'Espagne, Op. 232: No. 4. Cordoba",
#   'https://www.naxos.com/catalogue/item.asp?item_code=ODE752-2',
#   'ODE752-2',
#   'Girlfight (2000)'],
#  ['ALBINONI, TOMASO GIOVANNI',
#   'Adagio',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550014',
#   '8.550014',
#   'Doors (The) (1991)?;Gallipoli (1981)?;Inbetweeners 2 (The) (2014)?;Rio das Mortes (1971)?;Rollerball (1975)?;Welcome to Sarajevo (1997)'],
#  ['ALBINONI, TOMASO GIOVANNI',
#   'Oboe Concerto in B-flat major, Op. 9, No. 11',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550739',
#   '8.550739',
#   'Elle (2016)'],
#  ['ALBINONI, TOMASO GIOVANNI',
#   'Oboe Concerto in C major, Op. 7, No. 12',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553035',
#   '8.553035',
#   'Peter Rabbit (2018)'],
#  ['ALFVEN, HUGO',
#   'Swedish Rhapsody No. 1',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550090',
#   '8.550090',
#   "Young Poisoner's Handbook (The) (1995)"],
#  ['ALLEGRI, GREGORIO',
#   'Miserere mei',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550827',
#   '8.550827',
#   "Anatomy (2000)?;Angela's Ashes?;Chariots of Fire?;Face/Off (1997)?;Maurice (1987)?; Tout nouveau testament (Le) aka The Brand New Testament (2015)"],
#  ['ANDERSON, LEROY',
#   'Sleigh Ride',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.559125',
#   '8.559125',
#   'Girl, Interrupted (1999)'],
#  ['ARNE, THOMAS AUGUSTINE',
#   'Rule Brittania',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553961',
#   '8.553961',
#   'Alphabet Murders (The) (1965)?;BFG (The) (2016)?;Charge of the Light Brigade (The)?;Into the Arms of Strangers (2007)?;Minions (2015)?;Three Men and a Little Lady (1990)'],
#  ['BACH, CARL PHILIPP EMANUEL',
#   'Keyboard Sonata in E Major, Wq. 48/3, H. 26, "Prussian Sonata No. 3"',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.572674',
#   '8.572674',
#   'Casanova (2015)'],
#  ['BACH, JOHANN CHRISTIAN',
#   'Sinfonia in E-flat major: II. Andante con sordini',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553085',
#   '8.553085',
#   'Vertigo (1958)'],
#  ['BACH, JOHANN CHRISTIAN',
#   'String Quartet in B-flat major: II. Rondeau',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.557361',
#   '8.557361',
#   'Only You (1994)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Anna Magdalena Notenbuch (Clavier-Buchlein III): Bist du bei mir, BWV 508 (attrib. G.H. Stolzel)',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553751',
#   '8.553751',
#   'Gotter der Pest (Gods of the Plague) (1970)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Ave Maria',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553751',
#   '8.553751',
#   '28 Days Later (2002)?;Mad Dogs and Englishmen (1995)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Brandenburg Concerto No. 1 in F major, BWV 1046: I. Allegro',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554607',
#   '8.554607',
#   'Rounders (1988)?;Running on Empty'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Brandenburg Concerto No. 1 in F major, BWV 1046: III. Allegro',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554607',
#   '8.554607',
#   'Rounders (1988)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Brandenburg Concerto No. 2 in F major, BWV 1047',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554607',
#   '8.554607',
#   "Romy and Michele's High School Reunion (1997)"],
#  ['BACH, JOHANN SEBASTIAN',
#   'Brandenburg Concerto No. 2 in F major, BWV 1047: II. Andante',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554607',
#   '8.554607',
#   'Black and White (1999)?;Island of Dr Moreau (The)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Brandenburg Concerto No. 3 in G major, BWV 1048',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554607',
#   '8.554607',
#   'Boxing Helena (1993)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Brandenburg Concerto No. 3 in G major, BWV 1048: I. Allegro',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554607',
#   '8.554607',
#   "Die Hard (1988)?;Hannibal (2001)?;Lucky Break?;Moll Flanders (1996)?;Romy and Michele's High School Reunion (1997)"],
#  ['BACH, JOHANN SEBASTIAN',
#   'Brandenburg Concerto No. 3 in G major, BWV 1048: III. Allegro',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554607',
#   '8.554607',
#   "Romy and Michele's High School Reunion (1997)?;Spotlight (2015)"],
#  ['BACH, JOHANN SEBASTIAN',
#   'Brandenburg Concerto No. 4 in G major, BWV 1049',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554608',
#   '8.554608',
#   'High-Rise (2015)?;Tout nouveau testament (Le) aka The Brand New Testament (2015)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Brandenburg Concerto No. 4 in G major, BWV 1049: I. Allegro',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554608',
#   '8.554608',
#   'Cruel Intentions (1999)?;Miracle (2004)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Brandenburg Concerto No. 4 in G Major, BWV 1049: II. Andante',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554608',
#   '8.554608',
#   'Enigma (2001)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Brandenburg Concerto No. 4 in G major, BWV 1049: III. Presto',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554608',
#   '8.554608',
#   'Slaughterhouse Five (1972)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Brandenburg Concerto No. 5 in D major, BWV 1050: I. Allegro',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554608',
#   '8.554608',
#   'American President (The) (1995)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Brandenburg Concerto No. 6 in B-flat major, BWV 1051 : I. Allegro',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554607',
#   '8.554607',
#   'Mistress (1992)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Brandenburg Concerto No. 6 in B-flat major, BWV 1051 : III. Allegro',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554607',
#   '8.554607',
#   'Bridge Too Far (A) (1977)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Cantata, BWV 56: Komm, o Tod, du Schlafes Bruder',
#   'https://www.naxos.com/catalogue/item.asp?item_code=C67190',
#   'C67190',
#   'Pelican Brief (1993)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Cantata, BWV 147: Jesus bleibt meine Freude',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550642',
#   '8.550642',
#   'Boogie Nights (1997)?;Brooklyn (2015)?;Brown Sugar (2002)?;Crush (2001)?;Cutting Edge (The) (1992)?;Flubber (1997)?;League of Their Own (A) (1992)?;Minority Report (2002)?;Paradise Road (1997)?;Picture Perfect (1997)?;Runaway Bride (1999)?;Stealing Home (1988)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Capriccio on the Departure of his Most Beloved Brother, BWV 992',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550692',
#   '8.550692',
#   'Call Me by Your Name (2017)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Cello Suite No. 1 in G major, BWV 1007',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.557280-81',
#   '8.557280-81',
#   'Flatliners (2017)?;Killing Box (The) (1993)?;Pianist (The) (2002)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Cello Suite No. 1 in G major, BWV 1007: I. Prelude',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.557280-81',
#   '8.557280-81',
#   "Antonia's Line (1995)?;Beginners (2010)?;Choice (The) (2016)?;Elysium (2013)?;Ex Machina (2015)?;Hoje Eu Quero Voltar Sozinho (The Way He Looks) (2014)?;How Not to Disappear Completely (2015)?;Irrational Man (2015)?;J'embrasse pas (1991)?;Maniac (2013)?;Master and Commander: The Far Side of the World (2003)?;MI-5 (Spooks: The Greater Good) (2015)?;?;Music of the Heart (1999)?;Riot (2018)?;Simple Twist of Fate (A) (1994)?;Still Alice (2014)"],
#  ['BACH, JOHANN SEBASTIAN',
#   'Cello Suite No. 1 in G major, BWV 1007: VI. Gigue',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.557280-81',
#   '8.557280-81',
#   'Hilary and Jackie (1998)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Cello Suite No. 2 in D minor, BWV 1008: IV. Sarabande',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.557280-81',
#   '8.557280-81',
#   'Through a Glass Darkly (1961)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Cello Suite No. 3 in C major, BWV 1009',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.557280-81',
#   '8.557280-81',
#   'Brothers Grimsby (The) (2016)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Cello Suite No. 3 in C major, BWV 1009: I. Prelude',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.557280-81',
#   '8.557280-81',
#   'Accountant (The) (2016)?;Hilary and Jackie (1998)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Cello Suite No. 3 in C major, BWV 1009: II. Allemande',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.557280-81',
#   '8.557280-81',
#   'Casa Grande (2014)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Cello Suite No. 3 in C major, BWV 1009: V. Bourree I and II',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.557280-81',
#   '8.557280-81',
#   'Casa Grande (2014)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Cello Suite No. 4 in E-flat major, BWV 1010: I. Prelude',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.557280-81',
#   '8.557280-81',
#   'Late Quartet (A) (2012)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Cello Suite No. 4 in E-flat major, BWV 1010: II. Allemande',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.557280-81',
#   '8.557280-81',
#   'Late Quartet (A) (2012)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Cello Suite No. 4 in E-flat major, BWV 1010: IV. Sarabande',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.557280-81',
#   '8.557280-81',
#   'Autumn Sonata (1978)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Cello Suite No. 5 in C minor, BWV 1011: I. Prelude',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.557280-81',
#   '8.557280-81',
#   'Casa Grande (2014)?;Homesick (I) (2015)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Cello Suite No. 5 in C minor, BWV 1011: IV. Sarabande',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.557280-81',
#   '8.557280-81',
#   'Cries and Whispers (1972)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Cello Suite No. 6 in D major, BWV 1012',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.557280-81',
#   '8.557280-81',
#   'Another Woman (1988)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Cello Suite No. 6 in D major, BWV 1012: V. Gavotte I and II',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.557280-81',
#   '8.557280-81',
#   'Hilary and Jackie (1998)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Concerto for 2 Harpsichords in C minor, BWV 1060: II. Largo ovvero adagio',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554606',
#   '8.554606',
#   'Barry Lyndon (1975)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Concerto for 2 Violins in D minor, BWV 1043',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550194',
#   '8.550194',
#   'Bad Company (2002)?;Music of the Heart (1999)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Concerto for 2 Violins in D minor, BWV 1043 : I. Vivace',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550194',
#   '8.550194',
#   'Hannah and Her Sisters (1986)?;Hellraiser III: Hell on Earth (1992)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Concerto for 2 Violins in D minor, BWV 1043: II. Largo ma non tanto',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550194',
#   '8.550194',
#   "Caveman's Valentine (The) (2001)?;Children of a Lesser God (1986)?;Island of Dr Moreau (The)?;Thor: Ragnarok (2017)?;Torrents of Spring (1989)"],
#  ['BACH, JOHANN SEBASTIAN',
#   'Concerto for 4 Harpsichords in A minor, BWV 1065',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554606',
#   '8.554606',
#   'Dangerous Liaisons (1988)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Concerto in the Italian Style, BWV 971, "Italian Concerto": I. Allegro',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550709',
#   '8.550709',
#   'Talented Mr Ripley (The) (1999)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Concerto in the Italian Style, BWV 971, "Italian Concerto": III. Presto',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550709',
#   '8.550709',
#   'Harvard Man (2001)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'English Suite No. 2 in A minor, BWV 807',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553012',
#   '8.553012',
#   'Crimes and Misdemeanours (1989)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'English Suite No. 2 in A minor, BWV 807: I. Prelude',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553012',
#   '8.553012',
#   'Glenn Gould (32 Short Films about) (1993)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'English Suite No. 2 in A minor, BWV 807: II. Allemande',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553012',
#   '8.553012',
#   'Unbreakable (2000)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'English Suite No. 2 in A minor, BWV 807: V. Bourree I and II',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553012',
#   '8.553012',
#   "Schindler's List (1993)"],
#  ['BACH, JOHANN SEBASTIAN',
#   'English Suite No. 2 in A minor, BWV 807: VI. Gigue',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553012',
#   '8.553012',
#   'Glenn Gould (32 Short Films about) (1993)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'English Suite No. 5 in E minor, BWV 810: I. Prelude',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553013',
#   '8.553013',
#   'Glenn Gould (32 Short Films about) (1993)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Fantasia in C minor, BWV 562',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553032',
#   '8.553032',
#   'Favourite (The) (2018)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Flute Sonata in C major, BWV 1033: IV. Menuet I and II',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553755',
#   '8.553755',
#   'Perdita Durango (1997)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Flute Sonata in E-flat major, BWV 1031: II. Siciliano',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553754',
#   '8.553754',
#   'Breaking the Waves (1996)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'French Suite No. 1 in D minor, BWV 812: III. Sarabande',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550709',
#   '8.550709',
#   'Glenn Gould (32 Short Films about) (1993)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Fugue in C major, BWV 952',
#   'https://naxosmusiclibrary.com/catalogue/item.asp?cid=NI5689-90',
#   'NI5689-90',
#   'Unbreble (2000)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Fugue in C major, BWV 953',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553097',
#   '8.553097',
#   'Unbreakable (2000)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Goldberg Variations, BWV 988',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550078',
#   '8.550078',
#   'Last Castle (The) (2001)?;Love (II) (2015)?;Maurice (1987)?;Murder by Numbers (2002)?;No Letting Go (2015)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Goldberg Variations, BWV 988: Aria',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550078',
#   '8.550078',
#   "Amant double (L') (Double Lover) (2017)?;Before Sunrise (1995)?;English Patient (The) (1996)?;Hannibal (2001)?;Silence of the Lambs (The) (1991)"],
#  ['BACH, JOHANN SEBASTIAN',
#   'Goldberg Variations, BWV 988: Aria and Variation 19',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550078',
#   '8.550078',
#   'Glenn Gould (32 Short Films about) (1993)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Goldberg Variations, BWV 988: Variation 15',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550078',
#   '8.550078',
#   'Solaris (2002)?;Before Sunrise (1995)?;Hannibal (2001)?;Terminal Man (The) (1974)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Goldberg Variations, BWV 988: VIII. Variation 7',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550078',
#   '8.550078',
#   'Silence of the Lambs (The) (1991)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Harpsichord Concerto in D major, BWV 1054',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550422',
#   '8.550422',
#   'Love Story (1970)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Harpsichord Concerto in F minor, BWV 1056',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550423',
#   '8.550423',
#   'Well (The) (1997)?;Portrait of a Lady (The) (1996)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Harpsichord Concerto in F minor, BWV 1056: II. Largo',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550423',
#   '8.550423',
#   'Hannah and Her Sisters (1986)?;Lara Croft: Tomb Raider (2001)?;Primal Fear (1996)?;Slaughterhouse Five (1972)'],
#  ['BACH, JOHANN SEBASTIAN',
#   "Herz und Mund und Tat und Leben, BWV 147: Jesu, Joy of Man's Desiring (arr. for organ)",
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553859',
#   '8.553859',
#   'Muppets Most Wanted (2014)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Herzlich tut mich verlagen, BWV 727',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.223452',
#   '8.223452',
#   'Trainspotting (1996)'],
#  ['BACH, JOHANN SEBASTIAN',
#   "Ich ruf' zu Dir, Herr Jesu Christ (I call on you, Lord Jesus Christ), BWV 639",
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553032',
#   '8.553032',
#   'Amour (2012)?;Dr Jekyll and Mr Hyde (1931)?;Nymphomaniac: Vol. I (2013)?;Solaris (2002)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Invention No. 1 in C major, BWV 772',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550679',
#   '8.550679',
#   'Still Breathing (1997)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Invention No. 8 in F major, BWV 779',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550679',
#   '8.550679',
#   'Boomerang (1992)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Invention No. 13 in A minor, BWV 784',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550679',
#   '8.550679',
#   'Glenn Gould (32 Short Films about) (1993)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Invention No. 14 in B-flat major, BWV 785',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550679',
#   '8.550679',
#   'Ice Storm (The) (1997)'],
#  ['BACH, JOHANN SEBASTIAN',
#   "Keyboard Concerto in D Minor, BWV 974 (arr of A. Marcello's Oboe Concerto): II. Adagio",
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.572006-07',
#   '8.572006-07',
#   'Fifty Shades of Grey (2015)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Lobet den Herrn, alle Heiden, BWV 230',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553823',
#   '8.553823',
#   'Oscar and Lucinda (1997)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Mass in B minor, BWV 232',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550585-86',
#   '8.550585-86',
#   'Me and Earl and the Dying Girl (2015)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Mass in B minor, BWV 232: Gloria in excelsis Deo',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550585-86',
#   '8.550585-86',
#   'Three Kings (1999)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Mass in B minor, BWV 232: Et resurrexit',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550585-86',
#   '8.550585-86',
#   'Man Trouble (1992)'],
#  ['BACH, JOHANN SEBASTIAN',
#   "Organ Concerto in A minor, BWV 593 (arr. of Vivaldi's Violin Concerto in A minor, RV 522)",
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550936',
#   '8.550936',
#   'Scare Campaign (2016)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Overture (Suite) No. 1 in C major, BWV 1066: VI. Bourree I and II',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554609',
#   '8.554609',
#   'Story of Us (The) (1999)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Overture (Suite) No. 2 in B minor, BWV 1067: VI. Minuet',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554609',
#   '8.554609',
#   'Father of the Bride (1991)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Overture (Suite) No. 2 in B minor, BWV 1067: VII. Badinerie',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554609',
#   '8.554609',
#   'Father of the Bride (1991)?;Spider-Man 2 (2004)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Overture (Suite) No. 3 in D major, BWV 1068',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554609',
#   '8.554609',
#   'Below Utopia (1997)?;Beyond Utopia (1984)?;Bullets, Fangs and Dinner at 8 (2015)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Overture (Suite) No. 3 in D major, BWV 1068: I. Ouverture',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554609',
#   '8.554609',
#   'Hilary and Jackie (1998)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Overture (Suite) No. 3 in D major, BWV 1068: II. Air',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550245',
#   '8.550245',
#   "After Hours (1985)?;Devil's Advocate (The) (1997)?;Equals (2015)?;Heartbreakers (2001)?;I Married a Strange Person! (1997)?;Moll Flanders (1996)?;One Night Stand (1997)?;Runaway Bride (1999)?;Scouts Guide to the Zombie Apocalypse (2015)?;Seven (1995)?;Spy Who Loved Me (The) (1977)"],
#  ['BACH, JOHANN SEBASTIAN',
#   'Overture (Suite) No. 3 in D major, BWV 1068: III. Gavotte I and II',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554609',
#   '8.554609',
#   'In the Line of Fire (1993)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Overture (Suite) No. 3 in D major, BWV 1068: IV. Bourree',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554609',
#   '8.554609',
#   'Master of Disguise (The) (2002)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Partita No. 1 in B-flat major, BWV 825',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550692',
#   '8.550692',
#   "Couch in New York (A) (1996)?;Lee Daniels' The Butler (I) (2013)"],
#  ['BACH, JOHANN SEBASTIAN',
#   'Partita No. 2 in D minor, BWV 1004: V. Ciaccona',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550570',
#   '8.550570',
#   'Joueur de violon (1994)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Partita No. 4 in D major, BWV 828: III. Courante',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550693',
#   '8.550693',
#   'Exposed (1983)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Passacaglia and Fugue in C minor, BWV 582: I. Passacaglia',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553859',
#   '8.553859',
#   'White Nights (1985)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Pastorale in F major, BWV 590: III. Aria',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550184',
#   '8.550184',
#   'Favourite (The) (2018)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Prelude and Fughetta in G major, BWV 902',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550692',
#   '8.550692',
#   'Unbreakable (2000)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Prelude in D minor, BWV 926',
#   'https://naxosmusiclibrary.com/catalogue/item.asp?cid=827969301623',
#   '827969301623',
#   'Glenn Gould (32 Short Films about) (1993)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'St. Matthew Passion, BWV 244',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550832-34',
#   '8.550832-34',
#   'Hotel (2001)?;Japon (2002)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'St. Matthew Passion, BWV 244: Aus Liebe will mein Heiland sterben!',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550832-34',
#   '8.550832-34',
#   'You Can Count on Me (2000)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'St. Matthew Passion, BWV 244: Erbarme dich',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550832-34',
#   '8.550832-34',
#   'Divided We Fall (2000)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'St. Matthew Passion, BWV 244: Erkenne mich, mein Huter',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550832-34',
#   '8.550832-34',
#   'Come See the Paradise (1990)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'St. Matthew Passion, BWV 244: Kommt, ihr Tochter, helft mir klagen!',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550832-34',
#   '8.550832-34',
#   'THX 1138 (1971)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'St. Matthew Passion, BWV 244: Mache dich, mein Herze rein',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550832-34',
#   '8.550832-34',
#   'Talented Mr Ripley (The) (1999)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'St. Matthew Passion, BWV 244: Wir setzen uns mit Tranen nieder',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550832-34',
#   '8.550832-34',
#   'Casino (1995)?;White Room (1990)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'The Art of Fugue: Counterpoint 9',
#   'https://naxosmusiclibrary.com/catalogue/item.asp?cid=696998775923',
#   '696998775923',
#   'Glenn Gould (32 Short Films about) (1993)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'The Art of Fugue: Counterpoints 3 and 11',
#   'https://naxosmusiclibrary.com/catalogue/item.asp?cid=696998775923',
#   '696998775923',
#   'Fortress (1992)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'The Well-Tempered Clavier Book I: Prelude and Fugue No. 1 in C major, BWV 846',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553796-97',
#   '8.553796-97',
#   'Baghdad Cafe (1987)?;Entrapment (1999)?;Glenn Gould (32 Short Films about) (1993)?;Mr Nobody (2009)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'The Well-Tempered Clavier Book I: Prelude and Fugue No. 2 in C minor, BWV 847',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553796-97',
#   '8.553796-97',
#   'Chasing Amy (1997)?;Glenn Gould (32 Short Films about) (1993)?;Irrational Man (2015)?;Thick as Thieves'],
#  ['BACH, JOHANN SEBASTIAN',
#   'The Well-Tempered Clavier Book I: Prelude and Fugue No. 4 in C-sharp minor, BWV 849',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553796-97',
#   '8.553796-97',
#   'Marguerite (2015)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'The Well-Tempered Clavier Book I: Prelude and Fugue No. 12 in F minor, BWV 857',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553796-97',
#   '8.553796-97',
#   'Alias Betty (Betty Fisher and other stories) (2001)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'The Well-Tempered Clavier Book I: Prelude and Fugue No. 14 in F-sharp minor, BWV 859',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553796-97',
#   '8.553796-97',
#   'Glenn Gould (32 Short Films about) (1993)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'The Well-Tempered Clavier Book I: Prelude and Fugue No. 15 in G major, BWV 860',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553796-97',
#   '8.553796-97',
#   'Rise of the Planet of the Apes (2011)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'The Well-Tempered Clavier Book II: Prelude and Fugue No. 9 in E major, BWV 878',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550970-71',
#   '8.550970-71',
#   'Marguerite (2015)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'The Well-Tempered Clavier Book II: Prelude and Fugue No. 12 in F minor, BWV 857',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550970-71',
#   '8.550970-71',
#   'Red Dragon (2002)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'The Well-Tempered Clavier Book II: Prelude and Fugue No. 18 in G-sharp minor, BWV 887',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550970-71',
#   '8.550970-71',
#   'Irrational Man (2015)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Toccata and Fugue in D minor, BWV 565',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553859',
#   '8.553859',
#   "2000 Leagues Under the Sea (1954)?;976-EVIL (1988)?;Bad Boys II?;Barbarella (1968)?;Dr Jekyll and Mr Hyde (1931)?;Fantasia (1940)?;French Lieutenant's Woman (The) (1981)?;Gremlins II: The New Batch (1990)?;Marguerite (2015)?;Monty Python's The Meaning of Life (1997)?;Oh! What a Lovely War (1969)?;Quartet (2012)?;Rollerball (1975)?;Sour Grapes (1998)?;Sunset Blvd. (1950)?;Too Smooth (1998)?;Zoolander 2 (2016)"],
#  ['BACH, JOHANN SEBASTIAN',
#   'Toccata, Adagio and Fugue in C major, BWV 564: I. Toccata',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553859',
#   '8.553859',
#   'Bad Education Movie (The) (2015)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Toccata, Adagio and Fugue in C major, BWV 564: II. Adagio',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553859',
#   '8.553859',
#   'Sour Grapes (1998)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Viola da Gamba Sonata in G major, BWV 1027: I. Adagio',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.570210',
#   '8.570210',
#   'Before Sunrise (1995)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Violin Concerto in A minor, BWV 1041',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550194',
#   '8.550194',
#   'Portrait of a Lady (The) (1996)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Violin Concerto in A minor, BWV 1041: II. Andante',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550194',
#   '8.550194',
#   'On the Road (2012)?;Primal Fear (1996)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Violin Concerto in E major, BWV 1042',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550194',
#   '8.550194',
#   'Lost City of Z (The) (2016)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Violin Concerto in E major, BWV 1042: III. Allegro assai',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550194',
#   '8.550194',
#   'Patriot (The) (2000)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Violin Partita No. 1 in B minor, BWV 1002',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.570277-78',
#   '8.570277-78',
#   'Detours (2016)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Violin Partita No. 1 in B minor, BWV 1002: I. Allemanda',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.570277-78',
#   '8.570277-78',
#   'Sunday (2008)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Violin Partita No. 2 in D minor, BWV 1004: IV. Giga',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.570277-78',
#   '8.570277-78',
#   'Kiss the Girls (1997)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Violin Partita No. 2 in D minor, BWV 1004: V. Ciaconna',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.570277-78',
#   '8.570277-78',
#   'Beast with Five Fingers (1946)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Violin Partita No. 3 in E major, BWV 1006: I. Preludio',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.570277-78',
#   '8.570277-78',
#   'Truth About Cats and Dogs (The) (1996)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Violin Partita No. 3 in E major, BWV 1006: III. Gavotte en rondeau',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.570277-78',
#   '8.570277-78',
#   'Hunger (The) (1983)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Violin Sonata No. 1 in G minor, BWV 1001: I. Adagio',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554422',
#   '8.554422',
#   'Anniversary Party (2001)?;Kiss the Girls (1997)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Violin Sonata No. 1 in G minor, BWV 1001: IV. Presto',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554422',
#   '8.554422',
#   'Sandy Bottom Orchestra (The) (2000)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Violin Sonata No. 2 in A minor, BWV 1003: I. Grave',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554422',
#   '8.554422',
#   'One Night Stand (1997)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Vor deinen Thron tret ich (Before Thy throne I stand), BWV 668',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550927',
#   '8.550927',
#   'Enigma (2001)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Wachet auf, ruft uns die Stimme (Awake, the voice is calling), BWV 140',
#   'https://www.classicsonline.com/catalogue/product.aspx?cid=7318599919614',
#   '7318599919614',
#   "Mr Holland's Opus (1995)"],
#  ['BACH, JOHANN SEBASTIAN',
#   'Wachet auf! ruft uns die Stimme, BWV 645 (trans. W. Kempff)',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.223452',
#   '8.223452',
#   'Call Me by Your Name (2017)'],
#  ['BACH, JOHANN SEBASTIAN',
#   'Was mir behagt, ist nur die muntre Jagd, BWV 208, "Hunt Cantata": Schafe konnen sicher weiden from Was mir behagt, ist nur die muntre Jagd',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550643',
#   '8.550643',
#   'I Am Sam (2001)'],
#  ['BADARZEWSKA-BARANOWSKA, TEKLA',
#   "The Maiden's Prayer, Op. 4",
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550141',
#   '8.550141',
#   'Hi-Lo Country (The) (1998)?;Wedding Banquet (The) (1993)'],
#  ['BARBER, SAMUEL',
#   'Agnus Dei, Op. 11',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.559053',
#   '8.559053',
#   "Lorenzo's Oil (1992)"],
#  ['BARBER, SAMUEL',
#   'Adagio for Strings, Op. 11',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.559088',
#   '8.559088',
#   "Amelie of Montmartre (1980)?;Elephant Man (The) (1980)?;Jagarna (The Hunters) (1996)?;Kevin and Perry Go Large (2000)?;Lorenzo's Oil (1992)?;Platoon (1986)?;Roseaux Savages (Les) (1994)?;S1mOne (Simone) (2002)?;Scarlet Letter (The) (1995)"],
#  ['BARBER, SAMUEL',
#   'Violin Concerto, Op. 14: II. Andante',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.559044',
#   '8.559044',
#   'Deep Blue Sea (The) (2011)'],
#  ['BARRIOS MANGORE, AGUSTIN',
#   'La Catedral',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.555718',
#   '8.555718',
#   'Kissing Jessica Stein (2001)'],
#  ['BARRY, JOHN',
#   'Out of Africa: Main title theme',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.570505',
#   '8.570505',
#   'Le talent de mes amis (2015)'],
#  ['BARTOK, BELA',
#   'Music for Strings, Percussion and Celesta, Sz. 106',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550261',
#   '8.550261',
#   'Shining (The) (1980)'],
#  ['BARTOK, BELA',
#   'Music for Strings, Percussion and Celesta, Sz. 106: II. Allegro',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550261',
#   '8.550261',
#   'Being John Malkovich (1999)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   '32 Variations in C minor: Variations XXVI and XXVII',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550676',
#   '8.550676',
#   'Glenn Gould (32 Short Films about) (1993)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Bagatelle in A minor, WoO 59, "Fur Elise"',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550647',
#   '8.550647',
#   "Bill and Ted's Excellent Adventure (1989)?;Butcher Boy (The) (1997)?;Death in Venice (1971)?;Django Unchained (2012)?;Fearless (1993)?;Guilty (The) (2000)?;Immortal Beloved (1994)?;Lux in Tenebris (2016)?;My Life So Far (1999)?;Nymphomaniac: Vol. II (2013)?;Or So the Story Goes: Happy Thoughts (2015)?;Patch Adams (1998)?;Rosemary's Baby (1968)?;Walk (The) (II) (2015)?;Wrong Box (The) (1966)?;You Got Served (2004)"],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Bagatelle No. 2 in G minor, Op. 126: Allegro',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550474',
#   '8.550474',
#   'Amour (2012)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Cello Sonata No. 1 in F major, Op. 5, No. 1',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550479',
#   '8.550479',
#   'Horse Whisperer (The) (1998)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Cello Sonata No. 2 in G minor, Op. 5, No. 2',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550479',
#   '8.550479',
#   'Along Came Polly (2004)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Christus am Olberge (Christ on the Mount of Olives), Op. 85',
#   'https://naxosmusiclibrary.com/catalogue/item.asp?cid=CD98.422',
#   'CD98.422',
#   'Immortal Beloved (1994)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Collin\'s Coriolan, Op. 62, "Coriolan Overture": Overture',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550072',
#   '8.550072',
#   'Tangerine (2015)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Egmont, Op. 84: Overture',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.557264',
#   '8.557264',
#   'Lincoln (2012)?;Sunshine (1999)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Fantasia in C minor, Op. 80, "Choral Fantasy": Allegretto, ma non troppo',
#   'https://naxosmusiclibrary.com/catalogue/item.asp?cid=CAvi8553120',
#   'CAvi8553120',
#   'Oscar and Lucinda (1997)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Fidelio: Mir ist so wunderbar',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660070-71',
#   '8.660070-71',
#   'Onegin (1999)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Fidelio: O welche Lust (Chorus of Prisoners)',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660070-71',
#   '8.660070-71',
#   'Fidelio'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Minuet in G major, WoO 10, No. 6',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550646',
#   '8.550646',
#   'Heaven and Earth (1990)?;Music Man (The) (1962)?;Paradise Road (1997)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Missa Solemnis, Op. 123: Kyrie eleison',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.557060',
#   '8.557060',
#   'Immortal Beloved (1994)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Concerto No. 1 in C major, Op. 15',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550190',
#   '8.550190',
#   'Wild Card (2015)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Concerto No. 1 in C major, Op. 15: II. Largo',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550190',
#   '8.550190',
#   'Equals (2015)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Concerto No. 3 in C minor, Op. 37',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550122',
#   '8.550122',
#   'Into the Arms of Strangers (2007)?;Pianist (The) (2002)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Concerto No. 3 in C minor, Op. 37: I. Allegro con brio',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550122',
#   '8.550122',
#   'Equals (2015)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Concerto No. 4 in G major, Op. 58: III. Rondo',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550122',
#   '8.550122',
#   'Equals (2015)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Concerto No. 5 in E-flat major, Op. 73, "Emperor"',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550121',
#   '8.550121',
#   'Elysium (2013)?;Crime of Padre Armano?;Elysium (2013)?;Immortal Beloved (1994)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Concerto No. 5 in E-flat major, Op. 73, "Emperor": II. Adagio un poco mosso',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550121',
#   '8.550121',
#   "Dead Poets Society?;Down River (2013)?;Invincible (2001)?;King's Speech (The) (2010)?;Liberal Arts (2012)?;No Letting Go (2015)?;Picnic at Hanging Rock (1975)?;Tomorrow Never Dies (1997)"],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Concerto No. 5 in E-flat major, Op. 73, "Emperor": III. Rondo',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550121',
#   '8.550121',
#   'Fearless (1993)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Quintet in E-flat major, Op. 16: III. Andante cantabile',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550511',
#   '8.550511',
#   'Talented Mr Ripley (The) (1999)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Sonata No. 1 in F minor',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550150',
#   '8.550150',
#   'Traffic (2000)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Sonata No. 1 in F minor: II. Adagio',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550150',
#   '8.550150',
#   "Zookeeper's Wife (The) (2017)"],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Sonata No. 3 in C major, Op. 2, No. 3: II. Adagio',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550150',
#   '8.550150',
#   'Byzantium (2012)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Sonata No. 8 in C minor, Op. 13, "Pathetique"',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550045',
#   '8.550045',
#   "Elysium (2013)?;Man Who Wasn't There (The) (2001)?;Romy and Michele's High School Reunion (1997)"],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Sonata No. 8 in C minor, Op. 13, "Pathetique": I. Grave',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550045',
#   '8.550045',
#   'Immortal Beloved (1994)?;Star Trek: Insurrection (1998)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Sonata No. 8 in C minor, Op. 13, "Pathetique": II. Adagio cantabile',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550045',
#   '8.550045',
#   'Age of Innocence (The) (1993)?;Confessions of a Dangerous Mind (2002)?;Fontane Effi Briest (Effi Briest) (1974)?;Immortal Beloved (1994)?;Lost World: Jurassic Park (The) (1997)?;Mr Turner (2014)?;Wedding Ringer (The) (2015)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Sonata No. 8 in C minor, Op. 13, "Pathetique": III. Rondo',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550045',
#   '8.550045',
#   'Before Sunrise (1995)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Sonata No. 13 in E-flat major, Op. 27, No. 1, "Quasi una Fantasia": II. Allegro molto vivace',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550167',
#   '8.550167',
#   'Glenn Gould (32 Short Films about) (1993)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Sonata No. 14 in C-sharp minor, Op. 27, No. 2, "Moonlight"',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550045',
#   '8.550045',
#   "Crimson Tide (1995)?;K-19: The Widowmaker (2002)?;Loss of Sexual Innocence (The) (1999)?;Man Who Wasn't There (The) (2001)?;Pianist (The) (2002)?;SLC Punk! (1998)"],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Sonata No. 14 in C-sharp minor, Op. 27, No. 2, "Moonlight": I. Adagio sostenuto',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550045',
#   '8.550045',
#   'Cruel Intentions 2 (2000)?;Far and Away (1992)?;Fontane Effi Briest (Effi Briest) (1974)?;Gaslight (1944)?;Immortal Beloved (1994)?;Misery (1990)?;Peanuts Movie (The) (2015)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Sonata No. 14 in C-sharp minor, Op. 27, No. 2, "Moonlight": III. Presto agitato',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550045',
#   '8.550045',
#   'Immortal Beloved (1994)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Sonata No. 15 in D Major, Op. 28, "Pastoral"',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550255',
#   '8.550255',
#   "Man Who Wasn't There (The) (2001)"],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Sonata No. 16 in G major, Op. 31, No. 1: II. Adagio grazioso',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550166',
#   '8.550166',
#   'Search and Destroy (1995)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Sonata No. 17 in D minor, Op. 31, No. 2, "Tempest": III. Allegretto',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550054',
#   '8.550054',
#   'Glenn Gould (32 Short Films about) (1993)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Sonata No. 23 in F minor, Op. 57, "Appassionata"',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550045',
#   '8.550045',
#   "Man Who Wasn't There (The) (2001)?;My Life So Far (1999)?;Shine (1996)"],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Sonata No. 23 in F minor, Op. 57, "Appassionata": II. Andante con moto',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550045',
#   '8.550045',
#   'True Story (I) (2015)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Sonata No. 23 in F minor, Op. 57, "Appassionata": III. Allegro ma non troppo',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550045',
#   '8.550045',
#   'Hard Target (1993)?;Madame Souzatska (1988)?;True Story (I) (2015)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Sonata No. 25 in G Major, Op. 79',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550161',
#   '8.550161',
#   "Man Who Wasn't There (The) (2001)"],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Sonata No. 28 in A major, Op. 101',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.571258',
#   '8.571258',
#   'Love Is Strange (2014)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Sonata No. 30 in E major, Op. 109',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550151',
#   '8.550151',
#   "Man Who Wasn't There (The) (2001)?;Trick (1999)"],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Sonata No. 30 in E major, Op. 109: III. Gesangvoll, mit innigster Empfindung: Andante molto cantabile ed espressivo',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.571268',
#   '8.571268',
#   'Lost City of Z (The) (2016)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Sonata No. 31 in A-flat major, Op. 110: I. Moderato cantabile, molto espressivo',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550151',
#   '8.550151',
#   'Equals (2015)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Trio in B-flat major, Op. 97, "Archduke"',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550442',
#   '8.550442',
#   "Man Who Wasn't There (The) (2001)"],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Trio in B-flat major, Op. 97, "Archduke": I. Allegro Moderato',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550442',
#   '8.550442',
#   'Hilary and Jackie (1998)?;Swing Kids (1993)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Piano Trio in D major, Op. 70, No. 1, "Ghost": II. Largo assai ed espressivo',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550948',
#   '8.550948',
#   'Colonel Chabert (1994)?;Immortal Beloved (1994)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'String Quartet No. 2 in G major, Op. 18, No. 2',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550558',
#   '8.550558',
#   'Beginners (2010)?;Sour Grapes (1998)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'String Quartet No. 5 in A major, Op. 18, No. 5',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550560',
#   '8.550560',
#   'Daddy Day Care (2003)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'String Quartet No. 6 in B-flat major, Op. 18, No. 6',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550560',
#   '8.550560',
#   'George of the Jungle (1997)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'String Quartet No. 7 in F major, Op. 59, No. 1, "Rasumovsky"',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554181',
#   '8.554181',
#   'Sour Grapes (1998)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'String Quartet No. 13 in B-flat major, Op. 130: V. Cavatina',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554593',
#   '8.554593',
#   'Immortal Beloved (1994)?;One Night Stand (1997)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'String Quartet No. 14 in C-sharp minor, Op. 131',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554594',
#   '8.554594',
#   'After the Storm (2016)?;Late Quartet (A) (2012)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'String Trio in G major, Op. 9, No. 1',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.572377',
#   '8.572377',
#   'Company of Wolves (The) (1984)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Symphony No. 3 in E-flat major, Op. 55, "Eroica"',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553475',
#   '8.553475',
#   'Mission: Impossible - Rogue Nation (2015)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Symphony No. 3 in E-flat major, Op. 55, "Eroica": I. Allegro con brio',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553475',
#   '8.553475',
#   'Immortal Beloved (1994)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Symphony No. 3 in E-flat major, Op. 55, "Eroica": II. Marcia funebre',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553475',
#   '8.553475',
#   'This Is My Life (1992)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Symphony No. 3 in E-flat major, Op. 55, "Eroica": III. Scherzo',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553475',
#   '8.553475',
#   'Hitchcock (2012)?;Immortal Beloved (1994)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Symphony No. 5 in C minor, Op. 67',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553476',
#   '8.553476',
#   'Dysfunktional Family (2003)?;Love Potion No. 9 (1992)?;My Life So Far (1999)?;Peanuts Movie (The) (2015)'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Symphony No. 5 in C minor, Op. 67: I. Allegro con brio',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553476',
#   '8.553476',
#   'Austin Powers in Goldmember (2002)?;Bowfinger (1999)?;Breakfast Club (The) (1985)?;Celebrity Counterpoint (1967)?;Fantasia 2000?;Holy Man (1998)?;Immortal Beloved (1994)?;L.A. Story (1991)?;Longest Day (The) (1962)?;Mystery Men (1999)?;New Adventures of Pinocchio (The) (1999)?;Saboteur (1942)?;Saturday Night Fever (1977)?;Starsky & Hutch'],
#  ['BEETHOVEN, LUDWIG VAN',
#   'Symphony No. 5 in C minor, Op. 67: III. Allegro',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553476',
# ...
#   '8.553930',
#   'Grande bellezza (La) (The Great Beauty) (2013)?;Rope (1948)'],
#  ['POULENC, FRANCIS',
#   'Improvisation No. 15 in C minor: Tres vite',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553931',
#   '8.553931',
#   'Call Me by Your Name (2017)'],
#  ['POULENC, FRANCIS',
#   'Nocturne No. 1 in C major: Sans trainer',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553929',
#   '8.553929',
#   'Henry & June (1990)'],
#  ['POULENC, FRANCIS',
#   "Leocadia: Valse des chemins de l'amour",
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553615',
#   '8.553615',
#   'Henry & June (1990)'],
#  ['PROKOFIEV, SERGEY',
#   'Alexander Nevsky, Op. 78: II. Song about Alexander Nevsky',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.555710',
#   '8.555710',
#   'Anna Karenina (1997)?;Love and Death (1975)'],
#  ['PROKOFIEV, SERGEY',
#   'Alexander Nevsky, Op. 78: III. The Crusaders in Pskov',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.555710',
#   '8.555710',
#   'Apostate (The) (2015)'],
#  ['PROKOFIEV, SERGEY',
#   'Alexander Nevsky, Op. 78: V. The Battle on Ice',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.555710',
#   '8.555710',
#   'Apostate (The) (2015)?;Children of the Revolution (1996)'],
#  ['PROKOFIEV, SERGEY',
#   "Alexander Nevsky, Op. 78: VII. Alexander's Entry into Pskov",
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.555710',
#   '8.555710',
#   'Children of the Revolution (1996)'],
#  ['PROKOFIEV, SERGEY',
#   'Cinderella, Op. 87',
#   'https://naxosmusiclibrary.com/catalogue/item.asp?cid=3700403528336',
#   '3700403528336',
#   'Avengers: Age of Ultron (2015)'],
#  ['PROKOFIEV, SERGEY',
#   'Cinderella, Op. 87: Act III: Amoroso',
#   'https://naxosmusiclibrary.com/catalogue/item.asp?cid=3700403528336',
#   '3700403528336',
#   'Joy (2015)'],
#  ['PROKOFIEV, SERGEY',
#   'Lieutenant Kije Suite, Op. 60',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554057',
#   '8.554057',
#   'Children of the Revolution (1996)?;Isle of Dogs (2018)'],
#  ['PROKOFIEV, SERGEY',
#   "Lieutenant Kije Suite, Op. 60: III. Kije's Wedding",
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554057',
#   '8.554057',
#   'Crimson Tide (1995)?;Doc Hollywood (1991)?;Love and Death (1975)'],
#  ['PROKOFIEV, SERGEY',
#   'Lieutenant Kije Suite, Op. 60: IV. Troika',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.554057',
#   '8.554057',
#   'Love and Death (1975)'],
#  ['PROKOFIEV, SERGEY',
#   'Peter and the Wolf, Op. 67',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550499',
#   '8.550499',
#   "Animal House (National Lampoon's Animal House) (1978)?;Blade Runner 2049 (2017)?;Sour Grapes (1998)?;State of Play (2009)"],
#  ['PROKOFIEV, SERGEY',
#   'Peter and the Wolf, Op. 67: II. The Bird',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550499',
#   '8.550499',
#   'Minions (2015)'],
#  ['PROKOFIEV, SERGEY',
#   'Piano Sonata No. 7 in B-flat major, Op. 83: III. Precipitato',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553021',
#   '8.553021',
#   'Couch in New York (A) (1996)?;Glenn Gould (32 Short Films about) (1993)'],
#  ['PROKOFIEV, SERGEY',
#   'Romeo and Juliet, Op. 64',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553184-85',
#   '8.553184-85',
#   'Center Stage (2000)'],
#  ['PROKOFIEV, SERGEY',
#   'Romeo and Juliet, Op. 64: Balcony Scene',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553184-85',
#   '8.553184-85',
#   'Turning Point (1977)'],
#  ['PROKOFIEV, SERGEY',
#   'Romeo and Juliet, Op. 64: Dance of the Knight',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553184-85',
#   '8.553184-85',
#   'Purely Belter (2000)'],
#  ['PROKOFIEV, SERGEY',
#   'The Love for 3 Oranges Suite, Op. 33bis: III. March',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550381',
#   '8.550381',
#   'Love and Death (1975)'],
#  ['PROKOFIEV, SERGEY',
#   'Violin Concerto No. 2 in G minor, Op. 63',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553494',
#   '8.553494',
#   'Analyze This (1999)'],
#  ['PUCCINI, GIACOMO',
#   'Gianni Schicchi: Firenze e come un albero fiorito',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660111',
#   '8.660111',
#   'Room With a View (A) (1985)'],
#  ['PUCCINI, GIACOMO',
#   'Gianni Schicchi: O mio babbino caro',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660111',
#   '8.660111',
#   "Assassins (1995)?;Boxing Helena (1993)?;Captain Corelli's Mandolin (2001)?;G.I. Jane (1997)?;Italian for Beginners (Italiensk for begyndere) (2000)?;Julien Donkey-Boy (1999)?;Metro Manila (2013)?;Mystery Men (1999)?;Now You See Me 2 (2016)?;Prizzi's Honor (1985)?;Room With a View (A) (1985)?;Sing (2016)?;Speed 2: Cruise Control (1997)?;Tinseltown (1997)?;White Palace (1990)"],
#  ['PUCCINI, GIACOMO',
#   'La Boheme: Che gelida manina',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553151',
#   '8.553151',
#   "Crew (The) (2000)?;Great Caruso (The) (1951)?;Midsummer Night's Dream (A) (1999)?;Moonstruck (1987)?;One Chance (2013)?;Pushing Tin (1999)"],
#  ['PUCCINI, GIACOMO',
#   'La Boheme: Donde lieta usci',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553151',
#   '8.553151',
#   'Moonstruck (1987)'],
#  ['PUCCINI, GIACOMO',
#   'La boheme: O soave fanciulla',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553151',
#   '8.553151',
#   'Awakenings (1990)?;House of Last Things (The Last House) (2013)?;Moonstruck (1987)?;One Chance (2013)'],
#  ['PUCCINI, GIACOMO',
#   "La Boheme: Quando me'n vo'",
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553151',
#   '8.553151',
#   'Boxing Helena (1993)?;Mad City (1997)?;Moonstruck (1987)'],
#  ['PUCCINI, GIACOMO',
#   'La Boheme: Si, mi chiamo Mimi',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553151',
#   '8.553151',
#   'Good Thief (The) (I) (2002)?;Love Letter (The) (1999)'],
#  ['PUCCINI, GIACOMO',
#   'La Boheme: Sono andati',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553151',
#   '8.553151',
#   'Deep Impact (1998)?;Deer Hunter (1978)?;Heavenly Creatures (1994)'],
#  ['PUCCINI, GIACOMO',
#   'La Rondine: Chi il bel sogno di Doretta',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550605',
#   '8.550605',
#   'Hoodlum (1997)?;Room With a View (A) (1985)'],
#  ['PUCCINI, GIACOMO',
#   'Madama Butterfly',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660015-16',
#   '8.660015-16',
#   "House! (2000)?;Men, Women: User's Manual (1996)"],
#  ['PUCCINI, GIACOMO',
#   'Madama Butterfly: Bimba dagli occhi pieni ci malia',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660015-16',
#   '8.660015-16',
#   'Diamond Hunters (The)'],
#  ['PUCCINI, GIACOMO',
#   'Madama Butterfly: Con onor muore',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660015-16',
#   '8.660015-16',
#   'Fatal Attraction (1987)?;Sing (2016)'],
#  ['PUCCINI, GIACOMO',
#   'Madama Butterfly: Ecco! Son giunte',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553152',
#   '8.553152',
#   'House of Last Things (The Last House) (2013)?;Tetro (2009)'],
#  ['PUCCINI, GIACOMO',
#   'Madama Butterfly: Humming Chorus',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660015-16',
#   '8.660015-16',
#   'Jennifer Eight (Jennifer 8) (1992)?;Heavenly Creatures (1994)?;Natural Born Killers (1994)?;Tetro (2009)?;Under the Tuscan Sun (2003)'],
#  ['PUCCINI, GIACOMO',
#   'Madama Butterfly: Vogliatemi bene',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660015-16',
#   '8.660015-16',
#   'Death in Venice (1971)?;Household Saints (1993)?;Mona Lisa (1986)'],
#  ['PUCCINI, GIACOMO',
#   'Madame Butterfly: Un bel di, vedremo',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660015-16',
#   '8.660015-16',
#   "Bohemian Rhapsody (2018)?;Fatal Attraction (1987)?;M. Butterfly (1993)?;My Geisha (1962)?;One Fine Day (1996)?;Peter's Friends (1992)?;Riot (2018)?;Second Skin?;Victor/Victoria (1995)"],
#  ['PUCCINI, GIACOMO',
#   'Manon Lescaut: Donna non vidi mai simile a questa!',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660019-20',
#   '8.660019-20',
#   'Yes, Giorgio (1982)?;Victoria & Abdul (2017)'],
#  ['PUCCINI, GIACOMO',
#   'Manon Lescaut: In Quelle Trine Morbide',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660019-20',
#   '8.660019-20',
#   'All About the Benjamins (2002)'],
#  ['PUCCINI, GIACOMO',
#   "Manon Lescaut: L'ho abdandonato",
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660019-20',
#   '8.660019-20',
#   'Anywhere But Here (1999)'],
#  ['PUCCINI, GIACOMO',
#   'Manon Lescaut: Sola, perduta, abbandonata',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550606',
#   '8.550606',
#   'Hannah and Her Sisters (1986)'],
#  ['PUCCINI, GIACOMO',
#   'Tosca: E lucevan le stelle',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660001-02',
#   '8.660001-02',
#   'Great Caruso (The) (1951)?;Heavenly Creatures (1994)?;House! (2000)?;House of Last Things (The Last?;House) (2013)?;Jagarna (The Hunters) (1996)?;Man Who Cried (The) (2000)?;Serpico (1973)'],
#  ['PUCCINI, GIACOMO',
#   'Tosca: Recondita armonia',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660001-02',
#   '8.660001-02',
#   '40 Days and 40 Nights (2002)?;Love Letter (The) (1999)'],
#  ['PUCCINI, GIACOMO',
#   "Tosca: Vissi d'arte, vissi d'amore",
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660001-02',
#   '8.660001-02',
#   'Copycat (1995)?;Faithful (1996)?;Kid Stays in the Picture (The) (2002)?;Kin?;Not Without My Daughter (1991)?;Quartet (2012)?;Yves Saint Laurent (2014)'],
#  ['PUCCINI, GIACOMO',
#   'Turandot',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660089-90',
#   '8.660089-90',
#   'Centaurus (2015)'],
#  ['PUCCINI, GIACOMO',
#   'Turandot: Nessun dorma!',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660089-90',
#   '8.660089-90',
#   'Bend it Like Beckham (2002)?;Boxing Helena (1993)?;Boy Meets Girl (1994)?;Castaway (1986)?;Chasing Liberty (2004)?;House! (2000)?;Killing Fields (The) (1984)?;Mar adentro (The Sea Inside) (I) (2004)?;Mirror Has Two Faces (The) (1996)?;Mission: Impossible - Rogue Nation (2015)?;One Chance (2013)?;Sing (2016)?;Sum of All Fears (The) (2002)?;Toys (1992)?;Witches of Eastwick (The) (1987)?;Yes, Giorgio (1982)'],
#  ['PUCCINI, GIACOMO',
#   'Turandot: Popolo di Pekino!',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660089-90',
#   '8.660089-90',
#   'Mission: Impossible - Rogue Nation (2015)'],
#  ['PUCCINI, GIACOMO',
#   'Turandot: Signore, ascolta!',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660089-90',
#   '8.660089-90',
#   'Bohemian Rhapsody (2018)'],
#  ['PUCCINI, GIACOMO',
#   'Turandot: Tu, che di gel sei cinta',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.660089-90',
#   '8.660089-90',
#   'Life of David Gale (The) (2003)'],
#  ['PURCELL, HENRY',
#   'A New Ground in E minor, Z.T682',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553982',
#   '8.553982',
#   'Restoration'],
#  ['PURCELL, HENRY',
#   'Abdelazar Suite: V. Minuet',
#   'https://www.naxos.com/catalogue/item.asp?item_code=SVC-108HD',
#   'SVC-108HD',
#   'Restoration'],
#  ['PURCELL, HENRY',
#   'Dido and Aeneas, Z. 626 : Overture',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553108',
#   '8.553108',
#   'Before Sunrise (1995)'],
#  ['PURCELL, HENRY',
#   'Dido and Aeneas, Z. 626 : When I am laid in earth',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553108',
#   '8.553108',
#   'Last Supper (The)?;Man Who Cried (The) (2000)?;Mr Turner (2014)'],
#  ['PURCELL, HENRY',
#   'King Arthur, Z. 628, "The British Worthy": Overture',
#   'https://www.naxos.com/catalogue/item.asp?item_code=9.81079-80',
#   '9.81079-80',
#   'Restoration'],
#  ['PURCELL, HENRY',
#   'King Arthur, Z. 628, "The British Worthy": Second Overture',
#   'https://www.naxos.com/catalogue/item.asp?item_code=9.81079-80',
#   '9.81079-80',
#   'Restoration'],
#  ['PURCELL, HENRY',
#   'Music on the Death of Queen Mary: March, Z. 860A',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553129',
#   '8.553129',
#   'Clockwork Orange (A) (1971)'],
#  ['PURCELL, HENRY',
#   'O solitude, my sweetest choice, Z. 406',
#   'https://www.naxos.com/catalogue/item.asp?item_code=OC870',
#   'OC870',
#   'Brand New Testament (The) (2015)?;Tout nouveau testament (Le) aka The Brand New Testament (2015)'],
#  ['PURCELL, HENRY',
#   'Oedipus, King of Thebes, Z. 583: Music for a While',
#   'https://www.naxos.com/catalogue/item.asp?item_code=OC870',
#   'OC870',
#   'Favourite (The) (2018)'],
#  ['PURCELL, HENRY',
#   'Remember not, Lord, our offences, Z. 50',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553129',
#   '8.553129',
#   'Splitting Heirs (1993)'],
#  ['PURCELL, HENRY',
#   'Round O, Z. 684, "Abdelazer"',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553982',
#   '8.553982',
#   'Mimic'],
#  ['PURCELL, HENRY',
#   'The Fairy Queen, Z. 629',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550660-61',
#   '8.550660-61',
#   'Restoration'],
#  ['PURCELL, HENRY',
#   "The Gordion Knot Unty'd, Z. 597",
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.570149',
#   '8.570149',
#   'Kramer vs. Kramer (1979)'],
#  ['PURCELL, HENRY',
#   'The Indian Queen, Z. 630: The Masque of Fame and Envy',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553752',
#   '8.553752',
#   'Restoration'],
#  ['PURCELL, HENRY',
#   'The Indian Queen, Z. 630: Trumpet Tune',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.556839',
#   '8.556839',
#   'Other Sister (The) (1999)'],
#  ['PURCELL, HENRY',
#   'Trumpet Sonata in D major, Z. 850',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553444',
#   '8.553444',
#   'Kramer vs. Kramer (1979)'],
#  ['PURCELL, HENRY',
#   'Trumpet Sonata in D major, Z. 850: II. Adagio',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.553444',
#   '8.553444',
#   'Favourite (The) (2018)'],
#  ['PURCELL, HENRY',
#   'Welcome to all the pleasures: Here the Deities Approve',
#   'https://www.classicsonline.com/catalogue/product.aspx?cid=722056213325',
#   '722056213325',
#   'Restoration'],
#  ['RACHMANINOV, SERGEI',
#   '5 morceaux de fantaisie, Op. 3: No. 2 Prelude in C-sharp minor',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550348',
#   '8.550348',
#   'Day at the Races (A) (1937)?;Shine (1996)'],
#  ['RACHMANINOV, SERGEI',
#   'All-Night Vigil, Op. 37, "Vespers": Blessed is the Man',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.555908',
#   '8.555908',
#   'Little Odessa (1994)'],
#  ['RACHMANINOV, SERGEI',
#   'All-Night Vigil, Op. 37, "Vespers": Canticle of Simeon',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.555908',
#   '8.555908',
#   'Anna Karenina (1997)'],
#  ['RACHMANINOV, SERGEI',
#   'All-Night Vigil, Op. 37, "Vespers": Hymn of Thanksgiving to the Mother of God',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.555908',
#   '8.555908',
#   'Little Odessa (1994)'],
#  ['RACHMANINOV, SERGEI',
#   'All-Night Vigil, Op. 37, "Vespers": Polyeleopsalm',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.555908',
#   '8.555908',
#   "My Best Friend's Wedding (1997)"],
#  ['RACHMANINOV, SERGEI',
#   'Moments musicaux, Op. 16',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.571289',
#   '8.571289',
#   'Bad Company (2002)'],
#  ['RACHMANINOV, SERGEI',
#   'Piano Concerto No. 2 in C minor, Op. 18',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550117',
#   '8.550117',
#   'Center Stage (2000)?;Rhapsody (1954)'],
#  ['RACHMANINOV, SERGEI',
#   'Piano Concerto No. 2 in C minor, Op. 18: I. Moderato',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550810',
#   '8.550810',
#   'Seventh Veil (The)'],
#  ['RACHMANINOV, SERGEI',
#   'Piano Concerto No. 2 in C minor, Op. 18: II. Adagio sostenuto',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550117',
#   '8.550117',
#   'Brief Encounter (1945)?;Elle (2016)?;Seven Year Itch (The) (1955)'],
#  ['RACHMANINOV, SERGEI',
#   'Piano Concerto No. 3 in D minor, Op. 30',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550666',
#   '8.550666',
#   'Shine (1996)'],
#  ['RACHMANINOV, SERGEI',
#   'Piano Concerto No. 3 in D minor, Op. 30: I. Allegro ma non tanto',
#   'https://www.naxos.com/catalogue/item.asp?item_code=8.550349',
#   '8.550349',
#   'Undir trenu (Under the Tree) (2017)'],
#  ...]

# %% [markdown]
# We can now write this Python list to a CSV file:

# %%
out_data_file = "-".join([str(year), str(month), "untidy"])+".csv"
with open(out_data_file, "w") as file:
    csv.writer(file, delimiter=',').writerows(untidy_data)

# %% [markdown]
# The rest of the work will be in another notebook.
